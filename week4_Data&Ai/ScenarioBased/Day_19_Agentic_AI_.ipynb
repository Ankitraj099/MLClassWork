# %%
# Scenario-Based Teaching: Smart Travel Agent
# 🧑‍🏫 How You Start in Class

# Say this:

# “Imagine you are very busy and you tell your assistant:

# ‘Find me the best flight from Delhi to Mumbai.’

# Now instead of replying with just text, your assistant actually thinks,
# checks data, and gives a final decision.”


# Step 1 — Define Tools

# 👉  “Tools = functions the agent can call”

def search_flights(source, destination):
    return [
        {"airline": "IndiGo", "price": 4500, "time": "6:00 AM"},
        {"airline": "Air India", "price": 5200, "time": "9:00 AM"}
    ]

def check_weather(city):
    return {"city": city, "temperature": 28, "condition": "Clear"}

def calculate_budget(flights):
    cheapest = min(flights, key=lambda x: x["price"])
    return cheapest

# %%
# Step 2 — Agent Brain (Decision + Planning)
def agent_brain(user_query):
    plan = []

    if "flight" in user_query.lower():
        plan.append("search_flights")
        plan.append("check_weather")
        plan.append("choose_best")

    return plan

# %%
# Step 3 — Execution Engine
def execute_plan(plan):
    context = {}

    for step in plan:
        if step == "search_flights":
            print("\n[Action] Searching Flights...")
            context["flights"] = search_flights("Delhi", "Mumbai")
            print(context["flights"])

        elif step == "check_weather":
            print("\n[Action] Checking Weather...")
            context["weather"] = check_weather("Mumbai")
            print(context["weather"])

        elif step == "choose_best":
            print("\n[Action] Choosing Best Option...")
            best = calculate_budget(context["flights"])
            context["best_flight"] = best
            print(best)

    return context

# %%
# Step 4 — Full Agent
def travel_agent(user_query):
    print("User Query:", user_query)

    # Step 1: Plan
    plan = agent_brain(user_query)
    print("\n[Plan]", plan)

    # Step 2: Execute
    result = execute_plan(plan)

    # Step 3: Final Response
    final_output = f"""
Best Flight: {result['best_flight']['airline']} at ₹{result['best_flight']['price']}
Weather: {result['weather']['condition']}, {result['weather']['temperature']}°C
Recommendation: Book the cheapest early flight.
"""
    return final_output

# %%
# Step 5 — Run It
response = travel_agent("Find best flight from Delhi to Mumbai")
print("\nFinal Answer:\n", response)
# Out:
# User Query: Find best flight from Delhi to Mumbai
#
# [Plan] ['search_flights', 'check_weather', 'choose_best']
#
# [Action] Searching Flights...
# [{'airline': 'IndiGo', 'price': 4500, 'time': '6:00 AM'}, {'airline': 'Air India', 'price': 5200, 'time': '9:00 AM'}]
#
# [Action] Checking Weather...
# {'city': 'Mumbai', 'temperature': 28, 'condition': 'Clear'}
#
# [Action] Choosing Best Option...
# {'airline': 'IndiGo', 'price': 4500, 'time': '6:00 AM'}
#
# Final Answer:
#
# Best Flight: IndiGo at ₹4500
# Weather: Clear, 28°C
# Recommendation: Book the cheapest early flight.

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)

# %%
# Upgrade: Add Reasoning (VERY IMPORTANT)

def choose_best_flight(flights, weather):
    cheapest = min(flights, key=lambda x: x["price"])

    if weather["condition"] == "Rain":
        return "Avoid travel due to bad weather"

    return f"Choose {cheapest['airline']} at ₹{cheapest['price']}"

# %%
# Fraud Detection ReAct Agent (toy demo)
# Scenario: The Bank’s AI Fraud Agent
# Imagine a bank has deployed an AI-powered fraud detection agent named FraudLLM.
# Its job is to monitor transactions in real time and decide whether they are normal or suspicious.
# Step 1: Thinking (Reasoning)
# Whenever a transaction comes in, FraudLLM first analyzes the details:
# - Example: “Payment to overseas account” → FraudLLM thinks: “Analyzing transaction:
# Payment to overseas account”
# Step 2: Planning (Choosing an Action)
# Based on the thought, FraudLLM decides which tool to use:
# - If the transaction involves overseas transfers or multiple small deposits, it plans to flag as suspicious.
# - Otherwise, it plans to mark as normal.
# Step 3: Acting (Running Tools)
# FraudLLM hands over the decision to FraudTools, which executes the action:
# - flag_suspicious → returns “Suspicious Transaction”
# - mark_normal → returns “Normal Transaction”
# Step 4: Answering (Final Decision)
# Once a clear classification is reached, FraudLLM announces the decision:
# - “Decision: Suspicious Transaction”
# - “Decision: Normal Transaction”


class FraudLLM:
    def think(self, input_text):
        # Simulate reasoning
        return f"Analyzing transaction: {input_text}"

    def plan(self, thought):
        # Decide which tool to use
        if "overseas" in thought or "multiple deposits" in thought:
            return "flag_suspicious"
        else:
            return "mark_normal"

    def answer(self, obs):
        # Final answer
        return f"Decision: {obs}"

class FraudTools:
    def run(self, action):
        # Execute fraud detection actions
        if action == "flag_suspicious":
            return "Suspicious Transaction"
        elif action == "mark_normal":
            return "Normal Transaction"
        else:
            return "Unknown"

def is_final(obs):
    # Stop once we have a clear classification
    return "Transaction" in obs

# Instantiate components
llm = FraudLLM()
tools = FraudTools()

def react_agent(transaction):
    thought = llm.think(transaction)
    action = llm.plan(thought)
    obs = tools.run(action)

    # Loop until final decision
    while not is_final(obs):
        thought = llm.think(obs)
        action = llm.plan(thought)
        obs = tools.run(action)

    return llm.answer(obs)

# 🚀 Try it out
print(react_agent("Payment to overseas account"))
print(react_agent("Salary credited to employee account"))
print(react_agent("Multiple small deposits from different sources"))
# Out:
# Decision: Suspicious Transaction
# Decision: Normal Transaction
# Decision: Normal Transaction

# %%
# Fraud Detection ReAct Agent (toy demo)

class FraudLLM:
    def think(self, input_text):
        # Simulate reasoning
        return f"Analyzing transaction: {input_text}"

    def plan(self, thought):
        # Decide which tool to use
        if "overseas" in thought or "multiple deposits" in thought:
            return "flag_suspicious"
        else:
            return "mark_normal"

    def answer(self, obs):
        # Final answer
        return f"Decision: {obs}"

class FraudTools:
    def run(self, action):
        # Execute fraud detection actions
        if action == "flag_suspicious":
            return "Suspicious Transaction"
        elif action == "mark_normal":
            return "Normal Transaction"
        else:
            return "Unknown"

def is_final(obs):
    # Stop once we have a clear classification
    return "Transaction" in obs

# Instantiate components
llm = FraudLLM()
tools = FraudTools()

def react_agent(transaction):
    thought = llm.think(transaction)
    action = llm.plan(thought)
    obs = tools.run(action)

    # Loop until final decision
    while not is_final(obs):
        thought = llm.think(obs)
        action = llm.plan(thought)
        obs = tools.run(action)

    return llm.answer(obs)

# 🚀 Try it out
print(react_agent("Payment to overseas account"))
print(react_agent("Salary credited to employee account"))
print(react_agent("Multiple small deposits from different sources"))
# Out:
# Decision: Suspicious Transaction
# Decision: Normal Transaction
# Decision: Normal Transaction

# %%
Scenario: Smart Shopping Assistant 🛒
You say to your students:
“Imagine you are planning a party and you tell your assistant:
‘Find me the best chocolate cake under ₹500.’
Now instead of just replying with text, your assistant actually thinks, checks different bakery websites, compares prices, and then gives you the final decision.”

# %%
# !pip install openai langchain pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openai
#   Downloading openai-2.29.0-py3-none-any.whl.metadata (29 kB)
# Collecting langchain
#   Downloading langchain-1.2.12-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pandas in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (2.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from openai) (4.12.1)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.13.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from openai) (2.12.5)
# Collecting sniffio (from openai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>4 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Downloading langchain_core-1.2.19-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.1 (from langchain)
#   Downloading langgraph-1.1.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading langsmith-0.7.20-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.1->langchain)
#   Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.8 (from langgraph<1.2.0,>=1.1.1->langchain)
#   Downloading langgraph_prebuilt-1.0.8-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.1->langchain)
#   Downloading langgraph_sdk-0.3.11-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain)
#   Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.7)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.2.1)
# Requirement already satisfied: colorama in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-2.29.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    ------------------ --------------------- 0.5/1.1 MB 34.2 kB/s eta 0:00:19
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    --------------------------- ------------ 0.8/1.1 MB 33.4 kB/s eta 0:00:11
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ------------------------------------ --- 1.0/1.1 MB 28.1 kB/s eta 0:00:04
#    ---------------------------------------- 1.1/1.1 MB 25.4 kB/s  0:00:39
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.13.0-cp312-cp312-win_amd64.whl (205 kB)
# Downloading langchain-1.2.12-py3-none-any.whl (112 kB)
# Downloading langchain_core-1.2.19-py3-none-any.whl (503 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.1.2-py3-none-any.whl (167 kB)
# Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
# Downloading langgraph_prebuilt-1.0.8-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.11-py3-none-any.whl (94 kB)
# Downloading langsmith-0.7.20-py3-none-any.whl (359 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl (117 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, uuid-utils, sniffio, ormsgpack, jsonpatch, jiter, distro, requests-toolbelt, openai, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    -- -------------------------------------  1/16 [uuid-utils]
#    ----- ----------------------------------  2/16 [sniffio]
#    ---------- -----------------------------  4/16 [jsonpatch]
#    --------------- ------------------------  6/16 [distro]
#    --------------- ------------------------  6/16 [distro]
#    ----------------- ----------------------  7/16 [requests-toolbelt]
#    ----------------- ----------------------  7/16 [requests-toolbelt]
#    ----------------- ----------------------  7/16 [requests-toolbelt]
#    ----------------- ----------------------  7/16 [requests-toolbelt]
#    ----------------- ----------------------  7/16 [requests-toolbelt]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    -------------------- -------------------  8/16 [openai]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ---------------------- -----------------  9/16 [langsmith]
#    ------------------------- -------------- 10/16 [langgraph-sdk]
#    ------------------------- -------------- 10/16 [langgraph-sdk]
#    ------------------------- -------------- 10/16 [langgraph-sdk]
#    ------------------------- -------------- 10/16 [langgraph-sdk]
#    ------------------------- -------------- 10/16 [langgraph-sdk]
#    ------------------------- -------------- 10/16 [langgraph-sdk]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    --------------------------- ------------ 11/16 [langchain-core]
#    ------------------------------ --------- 12/16 [langgraph-checkpoint]
#    ------------------------------ --------- 12/16 [langgraph-checkpoint]
#    ------------------------------ --------- 12/16 [langgraph-checkpoint]
#    -------------------------------- ------- 13/16 [langgraph-prebuilt]
#    ----------------------------------- ---- 14/16 [langgraph]
#    ----------------------------------- ---- 14/16 [langgraph]
#    ----------------------------------- ---- 14/16 [langgraph]
#    ----------------------------------- ---- 14/16 [langgraph]
#    ----------------------------------- ---- 14/16 [langgraph]
#    ----------------------------------- ---- 14/16 [langgraph]
#    ----------------------------------- ---- 14/16 [langgraph]
#    ----------------------------------- ---- 14/16 [langgraph]
#    ----------------------------------- ---- 14/16 [langgraph]
#    ----------------------------------- ---- 14/16 [langgraph]
#    ----------------------------------- ---- 14/16 [langgraph]
#    ------------------------------------- -- 15/16 [langchain]
#    ------------------------------------- -- 15/16 [langchain]
#    ------------------------------------- -- 15/16 [langchain]
#    ------------------------------------- -- 15/16 [langchain]
#    ------------------------------------- -- 15/16 [langchain]
#    ------------------------------------- -- 15/16 [langchain]
#    ---------------------------------------- 16/16 [langchain]
#
# Successfully installed distro-1.9.0 jiter-0.13.0 jsonpatch-1.33 langchain-1.2.12 langchain-core-1.2.19 langgraph-1.1.2 langgraph-checkpoint-4.0.1 langgraph-prebuilt-1.0.8 langgraph-sdk-0.3.11 langsmith-0.7.20 openai-2.29.0 ormsgpack-1.12.2 requests-toolbelt-1.0.0 sniffio-1.3.1 uuid-utils-0.14.1 zstandard-0.25.0

# %%
import pandas as pd

data = [
    {"name": "Chocolate Truffle Cake", "price": 450, "rating": 4.5, "shop": "Sweet Treats"},
    {"name": "Dark Chocolate Cake", "price": 550, "rating": 4.7, "shop": "Cake World"},
    {"name": "Chocolate Cream Cake", "price": 300, "rating": 3.8, "shop": "Bake House"},
    {"name": "Premium Chocolate Cake", "price": 480, "rating": 4.6, "shop": "Delight Bakery"},
    {"name": "Budget Chocolate Cake", "price": 250, "rating": 3.5, "shop": "Local Bakers"}
]

df = pd.DataFrame(data)

def filter_cakes(max_price):
    filtered = df[df["price"] <= max_price]
    return filtered

def select_best_cake(filtered_df):
    if filtered_df.empty:
        return None
    best = filtered_df.sort_values(by="rating", ascending=False).iloc[0]
    return best

def smart_shopping_assistant(query):
    print("\n Processing Query:", query)

    max_price = 500
    if "500" in query:
        max_price = 500

    print(" Budget Detected:", max_price)

    filtered = filter_cakes(max_price)
    print("\n Available Options:")
    print(filtered)

    best_cake = select_best_cake(filtered)

    if best_cake is not None:
        result = f"""
Best Cake Found:
Name: {best_cake['name']}
Price: ₹{best_cake['price']}
Rating: {best_cake['rating']} 
Shop: {best_cake['shop']}
"""
    else:
        result = " No cake found under your budget."

    return result

query = "Find me the best chocolate cake under ₹500"
response = smart_shopping_assistant(query)

print(response)
# Out:
#  Processing Query: Find me the best chocolate cake under ₹500
#  Budget Detected: 500
#
#  Available Options:
#                      name  price  rating            shop
# 0  Chocolate Truffle Cake    450     4.5    Sweet Treats
# 2    Chocolate Cream Cake    300     3.8      Bake House
# 3  Premium Chocolate Cake    480     4.6  Delight Bakery
# 4   Budget Chocolate Cake    250     3.5    Local Bakers
#
# Best Cake Found:
# Name: Premium Chocolate Cake
# Price: ₹480
# Rating: 4.6
# Shop: Delight Bakery

# %% [markdown]
# Scenario: Smart Shopping Assistant 🛒
# You say to your students:
# “Imagine you are planning a party and you tell your assistant:
# ‘Find me the best chocolate cake under ₹500.’
# Now instead of just replying with text, your assistant actually thinks, checks different bakery websites, compares prices, and then gives you the final decision.”

# %%
import pandas as pd

data = [
    {"name": "Chocolate Truffle Cake", "price": 450, "rating": 4.5, "shop": "Sweet Treats"},
    {"name": "Dark Chocolate Cake", "price": 550, "rating": 4.7, "shop": "Cake World"},
    {"name": "Chocolate Cream Cake", "price": 300, "rating": 3.8, "shop": "Bake House"},
    {"name": "Premium Chocolate Cake", "price": 480, "rating": 4.6, "shop": "Delight Bakery"},
    {"name": "Budget Chocolate Cake", "price": 250, "rating": 3.5, "shop": "Local Bakers"}
]

df = pd.DataFrame(data)

def smart_shopping_assistant(query):
    max_price = 500

    filtered = df[df["price"] <= max_price].copy()

    if filtered.empty:
        return "No cake found under given budget"

    filtered["value_score"] = filtered["rating"] / filtered["price"]

    best = filtered.sort_values(by="value_score", ascending=False).iloc[0]

    return f"""
Best Cake Found (Smart Selection):
Name: {best['name']}
Price: ₹{best['price']}
Rating: {best['rating']} 
Shop: {best['shop']}
Score: {round(best['value_score'], 4)}
"""

query = "Find me the best chocolate cake under ₹500"
result = smart_shopping_assistant(query)

print(result)
# Out:
# Best Cake Found (Smart Selection):
# Name: Budget Chocolate Cake
# Price: ₹250
# Rating: 3.5
# Shop: Local Bakers
# Score: 0.014

# %% [markdown]
# Scenario: The University’s AI Plagiarism Agent
# Imagine a university has deployed an AI-powered plagiarism detection agent named PlagiarismLLM.
# Its job is to monitor student essay submissions in real time and decide whether they are original or potentially plagiarized.
#
# Step 1: Thinking (Reasoning)
# Whenever an essay is submitted, PlagiarismLLM first analyzes the text:
# - Example: “Essay contains large verbatim passages from online sources”
# - PlagiarismLLM thinks: “Analyzing essay: multiple verbatim passages detected.”
#
# Step 2: Planning (Choosing an Action)
# Based on the thought, PlagiarismLLM decides which tool to use:
# - If the essay has long verbatim matches or suspicious similarity scores, it plans to flag as potential plagiarism.
# - Otherwise, it plans to mark as original work.
#
# Step 3: Acting (Running Tools)
# PlagiarismLLM hands over the decision to PlagiarismTools, which executes the action:
# - flag_plagiarism → returns “Potential Plagiarism Detected”
# - mark_original → returns “Original Work”
#
# Step 4: Answering (Final Decision)
# Once a clear classification is reached, PlagiarismLLM announces the decision:
# - “Decision: Potential Plagiarism Detected”
# - “Decision: Original Work”

# %%
import re

class PlagiarismTools:
    def flag_plagiarism(self):
        return "Potential Plagiarism Detected"

    def mark_original(self):
        return "Original Work"


class PlagiarismLLM:
    def __init__(self):
        self.tools = PlagiarismTools()

    def think(self, essay):
        suspicious_phrases = [
            "according to wikipedia",
            "as stated in research paper",
            "Ai detected",
            "copy pasted"
        ]

        matches = sum(1 for phrase in suspicious_phrases if phrase in essay.lower())

        if matches > 0 or len(essay.split()) < 50:
            return "Suspicious content detected"
        return "Essay looks original"

    def plan(self, thought):
        if "Suspicious" in thought:
            return "flag"
        return "original"

    def act(self, action):
        if action == "flag":
            return self.tools.flag_plagiarism()
        return self.tools.mark_original()

    def run(self, essay):
        thought = self.think(essay)
        action = self.plan(thought)
        result = self.act(action)

        return f"""
Thought: {thought}
Action: {action}
Decision: {result}
"""


essay = """ machine learning is a field of AI. 
This essay does not contains copy pasted content."""

agent = PlagiarismLLM()
output = agent.run(essay)

print(output)
# Out:
# Thought: Suspicious content detected
# Action: flag
# Decision: Potential Plagiarism Detected

# %%
import requests

API_TOKEN = "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"
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"

API_URL = "https://router.huggingface.co/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}

def query_llm(prompt: str):
    payload = {
        "model": MODEL_ID,
        "messages": [
            {"role": "user", "content": prompt}
        ],
        "max_tokens": 200
    }

    response = requests.post(API_URL, headers=headers, json=payload)
    data = response.json()

    if "choices" in data:
        return data["choices"][0]["message"]["content"]
    else:
        return str(data)


def flag_suspicious(transaction):
    return "Suspicious Transaction"


def mark_normal(transaction):
    return "Normal Transaction"


def fraud_agent(transaction: str):
    thought = query_llm(f"Analyze this transaction: {transaction}")
    print("LLM Thought:", thought)

    if "overseas" in transaction.lower() or "multiple deposits" in transaction.lower():
        action = flag_suspicious
    else:
        action = mark_normal

    result = action(transaction)

    final_answer = query_llm(f"Decision: {result}")
    return final_answer


print(fraud_agent("Payment to overseas account"))
# Out:
# LLM Thought: **Transaction Analysis: Payment to Overseas Account**
#
# 1. **Transaction Type:** Payment
# 2. **Transaction Description:** Payment to an overseas account
# 3. **Transaction Details:**
#
# - **Date:** [Insert date]
# - **Amount:** [Insert amount in the local currency]
# - **Currency:** [Insert local currency]
# - **Beneficiary Name:** [Insert beneficiary name]
# - **Beneficiary Bank Account Number:** [Insert beneficiary bank account number]
# - **Beneficiary Bank Name:** [Insert beneficiary bank name]
# - **Beneficiary Bank Address:** [Insert beneficiary bank address]
# - **Beneficiary Country:** [Insert beneficiary country]
# - **Payment Method:** [Insert payment method, e.g., wire transfer, online transfer, etc.]
#
# **Analysis:**
#
# 1. **Risk Assessment:** Payments to overseas accounts can be high-risk transactions, especially if they involve large amounts or are initiated from a high-risk account.
# 2. **Anti-Money Laundering (AML) and Know Your
# **Suspicious Transaction Protocol**
#
# **Incident Overview:**
# A suspicious transaction has been detected, and an investigation is required to determine its legitimacy.
#
# **Transaction Details:**
#
# *   **Transaction Type:** [Insert transaction type, e.g., withdrawal, transfer, etc.]
# *   **Amount:** [Insert transaction amount]
# *   **Account Type:** [Insert account type, e.g., personal, business, etc.]
# *   **Location:** [Insert location, e.g., country, region, etc.]
# *   **Time:** [Insert time of transaction]
#
# **Investigation Steps:**
#
# 1.  **Verify Account Information:**
#     *   Review account holder information to ensure accuracy.
#     *   Check for any red flags, such as unusual account activity or inconsistent account holder information.
# 2.  **Review Transaction History:**
#     *   Examine the account's transaction history to identify any patterns or anomalies.
#     *   Check for any multiple transactions with similar characteristics.

# %% [markdown]
# 🏥 Scenario: The Hospital’s AI Appointment Agent
# Imagine a hospital has deployed an AI-powered agent named MediLLM.
# Its job is to monitor patient appointment requests and decide whether the requested slot is available or needs rescheduling.
#
# Step 1 — Thinking (Reasoning)
# Whenever a patient request comes in, MediLLM first analyzes the details:
# - Example: “Request for Dr. Sharma at 10 AM tomorrow”
# - MediLLM thinks: “Analyzing appointment request: Dr. Sharma, 10 AM tomorrow.”
#
# Step 2 — Planning (Choosing an Action)
# Based on the thought, MediLLM decides which tool to use:
# - If the requested slot is free, it plans to confirm appointment.
# - If the slot is already booked, it plans to suggest rescheduling.
#
# Step 3 — Acting (Running Tools)
# MediLLM hands over the decision to AppointmentTools, which executes the action:
# - confirm_slot → returns “Appointment Confirmed”
# - suggest_reschedule → returns “Slot Unavailable, Please Reschedule”
#
# Step 4 — Answering (Final Decision)
# Once a clear classification is reached, MediLLM announces the decision:
# - “Decision: Appointment Confirmed”
# - “Decision: Slot Unavailable, Please Reschedule”

# %%
import requests

API_TOKEN = "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"
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"

API_URL = "https://router.huggingface.co/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}


def query_llm(prompt: str):
    payload = {
        "model": MODEL_ID,
        "messages": [
            {"role": "user", "content": prompt}
        ],
        "max_tokens": 100
    }

    response = requests.post(API_URL, headers=headers, json=payload)
    data = response.json()

    if "choices" in data:
        return data["choices"][0]["message"]["content"].strip()
    return str(data)


class AppointmentTools:
    def confirm_slot(self):
        return "Appointment Confirmed"

    def suggest_reschedule(self):
        return "Slot Unavailable, Please Reschedule"


class MediLLM:
    def __init__(self):
        self.tools = AppointmentTools()
        self.booked_slots = {
            ("dr sharma", "10 am tomorrow"),
            ("dr sharma", "2 pm today")
        }

    def think(self, request):
        return query_llm(
            f"Analyze this appointment request in one line: {request}"
        )

    def plan(self, request):
        request_lower = request.lower()

        doctor = "dr sharma" if "sharma" in request_lower else "unknown"
        time = None

        if "10 am tomorrow" in request_lower:
            time = "10 am tomorrow"
        elif "2 pm today" in request_lower:
            time = "2 pm today"

        if (doctor, time) in self.booked_slots:
            return "reschedule"
        return "confirm"

    def act(self, action):
        if action == "confirm":
            return self.tools.confirm_slot()
        return self.tools.suggest_reschedule()

    def run(self, request):
        thought = self.think(request)
        action = self.plan(request)
        result = self.act(action)

        final = query_llm(
            f"""
Summarize the result in one line.

Thought: {thought}
Decision: {result}
"""
        )

        return f"""
Thought: {thought}
Action: {action}
Decision: {result}
Final Response: {final}
"""


request = "Request for Dr Sharma at 10 AM tomorrow"

agent = MediLLM()
output = agent.run(request)

print(output)
# Out:
# Thought: This is a brief, informal appointment request that lacks detail, specifically the date, patient's name, and reason for the visit, suggesting a casual or routine scheduling inquiry.
# Action: reschedule
# Decision: Slot Unavailable, Please Reschedule
# Final Response: The appointment request was declined due to a slot being unavailable, requiring the patient to reschedule.
