# %% [markdown]
# Scenario Question
#
# A biomedical researcher is designing a convolutional neural network (CNN) to analyze microscopic grayscale images of blood cells (64×64 pixels). She begins with a single convolutional layer defined as follows:
#
# Input: 64×64 grayscale images (1 channel)
# Convolutional Layer: 16 filters, each of size 5×5
# Stride: 1
# Padding: Same
# Activation Function: ReLU
# The goal of this layer is to extract local structural features such as cell boundaries and texture variations, which will later help in classifying whether the blood cells are healthy or show signs of abnormality.

# %%
# !pip install torch torchvision torchaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (2.10.0)
# Collecting torchvision
#   Using cached torchvision-0.25.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting torchaudio
#   Using cached torchaudio-2.10.0-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: filelock in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: setuptools in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch) (82.0.0)
# Requirement already satisfied: numpy in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torchvision) (12.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from jinja2->torch) (3.0.3)
# Using cached torchvision-0.25.0-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached torchaudio-2.10.0-cp312-cp312-win_amd64.whl (475 kB)
# Installing collected packages: torchvision, torchaudio
#
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    ---------------------------------------- 2/2 [torchaudio]
#
# Successfully installed torchaudio-2.10.0 torchvision-0.25.0

# %%
import torch
import torch.nn as nn

conv1 = nn.Conv2d(
            in_channels=1,      # grayscale image
            out_channels=16,    # number of filters
            kernel_size=5,      # 5x5 filter
            stride=1,
            padding=1          # padding
        )

x = torch.randn(1, 1, 64, 64)
output = conv1(x)
print("shape:", output.shape)
# Out:
# shape: torch.Size([1, 16, 62, 62])
