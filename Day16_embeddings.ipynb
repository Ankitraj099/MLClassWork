# %% [markdown]
# Scenario: Fitness & Wellness Chatbot Training
# You feed it these sentences:
# - “Push-ups strengthen chest and triceps”
# - “Yoga improves flexibility and balance”
# - “Apples are rich in fiber”
# - “Cardio exercises boost heart health”
# 👉 In this case, the chatbot learns to distinguish between exercise facts, nutrition facts, and general wellness statements, so it can tailor its responses — e.g., suggesting workouts, offering diet tips, or explaining health benefits.
# Would you like me to design a third scenario (maybe in education or travel) so you have a set of examples across different industries?

# %%
# !pip install sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.3.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (5.3.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: torch>=1.11.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: numpy in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (2.4.2)
# Requirement already satisfied: scikit-learn in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: h11>=0.16 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch>=1.11.0->sentence-transformers) (82.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: click>=8.2.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Downloading sentence_transformers-5.3.0-py3-none-any.whl (512 kB)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-5.3.0

# %%
from sentence_transformers import SentenceTransformer

# Load model
model_name = "all-MiniLM-L6-v2"
model = SentenceTransformer(model_name)

# Input sentences
texts = [
    "Push-ups strengthen chest and triceps",
    "Yoga improves flexibility and balance",
    "Apples are rich in fiber",
    "Cardio exercises boost heart health"
]

# Generate embeddings
embeddings = model.encode(texts)

# Print results
print(f"Model: {model_name}")
print(f"Embedding shape: {embeddings.shape}")
print(f"First vector sample: {embeddings[0][:10]}")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ANKIT RAJ\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Model: all-MiniLM-L6-v2
# Embedding shape: (4, 384)
# First vector sample: [-0.0062175   0.02071489 -0.0207071  -0.04770814 -0.03825501  0.05417699
#  -0.013364   -0.04778413 -0.08033789 -0.01570587]

# %%
## cosine similarity

import numpy as np

def cosine_similarity(a,b):
    return np.dot(a,b)/(np.linalg.norm(a)*np.linalg.norm(a))

a=np.array([0.2,0.8,-0.3,0.5])
b=np.array([0.1,0.9,-0.2,0.4])

print(cosine_similarity(a,b))
# Out:
# 0.9803921568627453

# %%
# Scenario: Warehouse Robot Navigation
# Imagine a warehouse where a robot needs to pick up items.
# - The robot is currently at position (1,2) on the warehouse grid.
# - The item it needs to collect is stored at position (4,6).
# The robot’s navigation system calculates the straight-line distance to the item so it knows how far it must travel if it moves directly.

# to find Euclidean distance
import numpy as np

a = np.array([1, 2])
b = np.array([4, 6])

distance = np.linalg.norm(a - b)

print(distance)
# Out:
# 5.0

# %%
# Scenario: Basketball Player Evaluation
# A coach is evaluating how well a player’s skills match the team’s current needs.
# - The team’s requirement vector is a = [2,5,1].
# - 2 = need for shooting ability
# - 5 = need for defense
# - 1 = need for passing
# - The player’s skill vector is b = [3,4,2].
# - 3 = player’s shooting ability
# - 4 = defensive ability
# - 2 = passing ability
# The coach calculates the dot product:

# to find Euclidean distance
import numpy as np

a = np.array([2,5,1])
b = np.array([3,4,2])

dot= np.dot(a,b)
print(dot)
# Out:
# 28

# %%
# # 🛒 Scenario: E‑Commerce Product Recommendations
# # Imagine you’re building a smart recommendation engine for an online store.
# # - Problem: Customers often search with phrases like “comfortable running shoes”,
#  but the catalog has items
# #  titled “lightweight sneakers for jogging”. Traditional keyword
#  search struggles to connect these.
# # - Solution: Use embeddings to capture semantic meaning of product 
# descriptions and customer queries.

import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# 🛒 Customer query embedding (semantic meaning of "comfortable running shoes")
query_embedding = np.array([0.1, 0.8, 0.5])

# 📦 Product catalog embeddings (semantic meaning of product descriptions)
product_embeddings = {
    "lightweight sneakers for jogging": np.array([0.2, 0.7, 0.6]),
    "formal leather shoes": np.array([0.9, 0.1, 0.2]),
    "sandals for summer": np.array([0.3, 0.4, 0.5])
}

# 🔍 Compute similarity between query and each product
for product, embedding in product_embeddings.items():
    similarity = np.dot(query_embedding, embedding)  # fast similarity check
    cosine_sim = cosine_similarity([query_embedding], [embedding])[0][0]  # normalized similarity
    print(f"{product} → Dot Product: {similarity:.3f}, Cosine Similarity: {cosine_sim:.3f}")

# ✅ Recommendation: pick the product with highest similarity
best_match = max(product_embeddings.items(), key=lambda x: np.dot(query_embedding, x[1]))
print("\nRecommended Product:", best_match[0])
# Out:
# lightweight sneakers for jogging → Dot Product: 0.880, Cosine Similarity: 0.983
# formal leather shoes → Dot Product: 0.270, Cosine Similarity: 0.307
# sandals for summer → Dot Product: 0.600, Cosine Similarity: 0.894
#
# Recommended Product: lightweight sneakers for jogging

# %% [markdown]
# 🎓 Scenario: Online Learning Platform Recommendations
# Imagine you’re building a smart recommendation engine for an online education platform.
# - Problem: Students often search with phrases like “beginner-friendly Python tutorials”, but the course catalog has items titled “Introduction to Programming with Python”. Traditional keyword search struggles to connect these because the words don’t match exactly.
# - Solution: Use embeddings to capture the semantic meaning of both student queries and course descriptions. By comparing embeddings with dot product or cosine similarity, the system can recommend the most relevant courses even when the wording is different

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

query_embedding = np.array([0.1, 0.8, 0.5])

course_embeddings = {
    "Introduction to Programming with Python": np.array([0.2, 0.7, 0.6]),
    "Advanced Machine Learning Techniques":    np.array([0.8, 0.9, 0.3]),
    "Web Development with HTML and CSS":       np.array([0.6, 0.2, 0.4]),
    "Data Science for Beginners":              np.array([0.3, 0.6, 0.5]),
    "Deep Learning with Neural Networks":      np.array([0.7, 0.8, 0.2]),
    "Database Management with SQL":            np.array([0.5, 0.1, 0.3]),
}

print(f"{'Course':<42} {'Dot Product':>11} {'Cosine Sim':>10}")

for course, embedding in course_embeddings.items():
    dot_sim    = np.dot(query_embedding, embedding)
    cosine_sim = cosine_similarity([query_embedding], [embedding])[0][0]
    print(f"{course:<42} {dot_sim:>11.3f} {cosine_sim:>10.3f}")


best_dot = max(course_embeddings.items(), key=lambda x: np.dot(query_embedding, x[1]))


best_cosine = max(course_embeddings.items(), 
                  key=lambda x: cosine_similarity([query_embedding], [x[1]])[0][0])

print(f"\n Student searched: 'beginner friendly Python tutorials'")
print(f"\n Recommended (Dot Product)  : {best_dot[0]}")
print(f" Recommended (Cosine Sim)   : {best_cosine[0]}")
# Out:
# Course                                     Dot Product Cosine Sim
# Introduction to Programming with Python          0.880      0.983
# Advanced Machine Learning Techniques             0.950      0.807
# Web Development with HTML and CSS                0.420      0.592
# Data Science for Beginners                       0.760      0.958
# Deep Learning with Neural Networks               0.810      0.789
# Database Management with SQL                     0.280      0.499
#
#  Student searched: 'beginner friendly Python tutorials'
#
#  Recommended (Dot Product)  : Advanced Machine Learning Techniques
#  Recommended (Cosine Sim)   : Introduction to Programming with Python

# %%
#  Scenario: Package Delivery in a City
# Imagine you run a delivery company in a huge city with 100,000 houses. Each house has a
#  unique “address fingerprint” (like the 384‑dimensional vectors in your code).
# Now, when a customer places an order, you need to quickly find the nearest warehouse or
#  delivery hub to their house. Instead of checking every single house one by one (which would 
# be very slow), you use smart strategies:

# 🗺️ HNSW (Hierarchical Navigable Small World)
# - Think of it like a layered city map:
# - Top layer = highways (coarse overview).
# - Middle layer = main roads.
# - Bottom layer = all streets and houses.
# - To find the nearest warehouse, you start at the highway level, zoom into the right district, 
# then finally navigate down to the exact street.
# - This is what IndexHNSWFlat does: it builds a graph of connections so you can “hop” quickly 
# to the right neighborhood.

# 🏘️ IVF (Inverted File Index)
# - Imagine dividing the city into 256 neighborhoods (Voronoi cells).
# - First, figure out which neighborhood the customer’s house belongs to.
# - Then, only search inside that neighborhood instead of the whole city.
# - This is what IndexIVFFlat does: it clusters vectors and searches only in the most relevant 
# clusters.
# - nprobe = 10 means you don’t just check one neighborhood, but the 10 most likely ones —
#  balancing speed and accuracy.

# ⚡ In Plain Words
# - HNSW = zooming in layer by layer on a city map.
# - IVF = splitting the city into neighborhoods and searching locally.
# - Both methods help you find the closest match fast without scanning all 100,000 houses.



import faiss
import numpy as np

d = 384       # embedding dimension
n = 100_000   # number of vectors

# ── HNSW index ──────────────────────────────
index = faiss.IndexHNSWFlat(d, 32)  # M=32 neighbours
index.hnsw.efConstruction = 200     # build quality
index.hnsw.efSearch = 100           # query quality

vectors = np.random.randn(n, d).astype("float32")
faiss.normalize_L2(vectors)         # L2 normalize
index.add(vectors)                  # add all vectors

query = np.random.randn(1, d).astype("float32")
faiss.normalize_L2(query)
D, I = index.search(query, k=10)    # top-10
print("Indices:", I[0])             # [2341, 8712, ...]
print("Distances:", D[0])           # cosine scores

# ── IVF index (faster for large scale) ──────
nlist = 256   # number of Voronoi cells
quantizer = faiss.IndexFlatL2(d)
index_ivf = faiss.IndexIVFFlat(quantizer, d, nlist)
index_ivf.train(vectors)
index_ivf.add(vectors)
index_ivf.nprobe = 10               # cells to search

# %%
# !pip install faiss-cpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.2-cp312-cp312-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from faiss-cpu) (2.4.2)
# Requirement already satisfied: packaging in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from faiss-cpu) (26.0)
# Downloading faiss_cpu-1.13.2-cp312-cp312-win_amd64.whl (18.9 MB)
#    ---------------------------------------- 0.0/18.9 MB ? eta -:--:--
#    ----- ---------------------------------- 2.6/18.9 MB 25.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 7.9/18.9 MB 23.2 MB/s eta 0:00:01
#    --------------------------- ------------ 12.8/18.9 MB 23.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 16.5/18.9 MB 21.7 MB/s eta 0:00:01
#    ---------------------------------------- 18.9/18.9 MB 19.2 MB/s  0:00:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.2

# %%
# !pip install chromadb sentence-transformers

import chromadb
from sentence_transformers import SentenceTransformer

# Load embedding model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Create Chroma client
client = chromadb.Client()

# FIX HERE
collection = client.get_or_create_collection("docs")

documents = [
    "Python is a high-level programming language",
    "Machine learning models need training data",
    "Dogs are loyal and friendly animals",
    "Cats are independent and curious pets",
]

# Create embeddings
embeddings = model.encode(documents).tolist()

# Add data
collection.add(
    documents=documents,
    embeddings=embeddings,
    ids=[f"doc{i}" for i in range(len(documents))],
    metadatas=[{"source": "demo", "idx": i} for i in range(len(documents))]
)

# Query
query = "can i enroll for machine learning?"
q_emb = model.encode([query]).tolist()

results = collection.query(
    query_embeddings=q_emb,
    n_results=3
)

for doc, dist in zip(results["documents"][0], results["distances"][0]):
    print(f"[{dist:.3f}] {doc}")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: chromadb in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (1.5.5)
# Requirement already satisfied: sentence-transformers in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (5.3.0)
# Requirement already satisfied: build>=1.0.3 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pydantic>=2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (2.12.5)
# Requirement already satisfied: pydantic-settings>=2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.41.0)
# Requirement already satisfied: numpy>=1.22.5 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (2.4.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.24.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (5.3.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: torch>=1.11.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: scikit-learn in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (26.0)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.28)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.3.2)
# Requirement already satisfied: anyio in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.27.0->chromadb) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.27.0->chromadb) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: h11>=0.16 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: pyproject_hooks in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.31.0)
# Requirement already satisfied: requests-oauthlib in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Requirement already satisfied: durationpy>=0.7 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Requirement already satisfied: sympy in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.73.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from pydantic>=2.0->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from torch>=1.11.0->sentence-transformers) (82.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [0.963] Machine learning models need training data
# [1.632] Python is a high-level programming language
# [1.980] Cats are independent and curious pets
