# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

result = generator("Machine learning is", max_length=40)

print(result)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "Machine learning is important to us because it's the most powerful way to help us solve common problems and build complex applications.\n\nWe've designed a simple application that allows you to set up a new job for a specific user. The job can be completed within minutes. Our new job is an interactive app that automatically finds your new job through a series of questions and answers.\n\nOur job is also a way to get feedback on the current user experience with our new interface. It allows us to take a look at your current user experience and learn how to improve on it.\n\nOur solution uses the Hadoop API, which is the best in the world. While working with Hadoop, we learned a lot about the fundamentals and concepts of how to create and deploy applications. We also learned how to use the Cloud Graph API to visualize data and perform analytics.\n\nWe also learned about the Open Source tools that we use to manage our data. In addition, we learned about the open source tools and the open source tools we use to make use of them.\n\nWhen you enter your email address, our email address will be automatically saved. Once you enter your email address, it will be automatically added to the database. So, when you use the API, our"}]

# %%
#  Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”


from transformers import pipeline

generator= pipeline("text-generation", model="gpt2")

result=generator("The hero enters the ancient forest and discovers", max_length=40)
print(result)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "The hero enters the ancient forest and discovers a lost land, the ruins of which belong to the king. He is then met by the villagers and the king, who sends them to the ruins to find out what happened to the hero.\n\nThe game has an action-packed plot, with the heroes' main character, Darrin, coming to the aid of Lulu, the young goddess of magic and history, and fighting back against the evil gods of the Ancient Gods. The game is well-balanced, with the hero and heroine taking turns fighting, and fighting their way through the game in turn, where the hero has to make sure his allies are safe from the evil gods.\n\nThe game is developed by Humble Studios, which is based in Los Angeles."}]

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Your system uses the BERT tokenizer to break the sentence into smaller units"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['your', 'system', 'uses', 'the', 'bert', 'token', '##izer', 'to', 'break', 'the', 'sentence', 'into', 'smaller', 'units']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "I have chest pain and shortness of breath"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Passing `generation_config` together with generation-related arguments=({'temperature', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence\n\nThe future of AI is in the hands of a group of people who have been working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time. They are now working on it for a long time'}]
# [{'generated_text': 'The future of Artificial Intelligence (AI) is already up in the air\n\nImage copyright Getty Images Image caption The University of Southampton\'s Artificial Intelligence Laboratory has developed new techniques for making new, smarter, and more efficient robots\n\nLast year the University of Southampton announced that a new approach developed by University of Southampton\'s Artificial Intelligence Laboratory (AILL) was to create new and better robots.\n\nAILL\'s main goal is to make robots smarter than humans, using machine learning techniques.\n\nThe company\'s latest developments include the ability to predict what robots will do, but also to create and integrate robotics capabilities into the software.\n\nThe aim is that the automated parts of robots could be developed over the next two to five years, in phases.\n\n"If we can identify the process by which machine learning methods can be used, we can create robots that are not just good at their job, but at their job," said Professor John Kahan of the University of Southampton\'s Artificial Intelligence Laboratory.\n\n"We will develop algorithms that will do just that."\n\nHe added that the AI lab is already under construction in a small, independent laboratory in Sussex, which is looking at artificial intelligence.\n\nImage copyright Getty Images Image caption The University of Southampton\'s AI Laboratory'}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling


from transformers import pipeline
generate=pipeline("text-generation",model="gpt2")

prompt="Interaction between human and robots"
result=generate(prompt,max_length=40,temperature=0.2)
print(result)

print ("high temperature")
result1=generate(prompt,max_length=40,temperature=0.8)
print(result1)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Interaction between human and robots is a major concern for the future of the human race.\n\nThe human-robot relationship is one of the most important issues facing the future of humanity. The human-robot relationship is one of the most important issues facing the future of humanity.\n\nThe human-robot relationship is one of the most important issues facing the future of humanity.\n\nThe human-robot relationship is one of the most important issues facing the future of humanity.\n\nThe human-robot relationship is one of the most important issues facing the future of humanity.\n\nThe human-robot relationship is one of the most important issues facing the future of humanity.\n\nThe human-robot relationship is one of the most important issues facing the future of humanity.\n\nThe human-robot relationship is one of the most important issues facing the future of humanity.\n\nThe human-robot relationship is one of the most important issues facing the future of humanity.\n\nThe human-robot relationship is one of the most important issues facing the future of humanity.\n\nThe human-robot relationship is one of the most important issues facing the future of humanity.\n\nThe human-robot relationship is one of the most important issues'}]
# high temperature
# [{'generated_text': 'Interaction between human and robots and the future of the human race is clearly underway.\n\nIn his most recent interview with the Guardian, Trump, who is currently in New York City to attend the World Economic Forum, said the "greatest threat" to humanity is "global warming."\n\n"It\'s the biggest problem that we\'re facing right now," he said. "Our biggest threat is global warming. It takes a lot of energy. And yet, we\'re able to do it."\n\n[Trump: I \'have the best global energy policy right now\']\n\nTrump also said that the "massive amount" of natural gas drilling in the United States comes from North Dakota, a state that Trump is in favor of having fully privatized.\n\nHe said the United States is building a "great, great, great, great infrastructure" on the ground and said the United States will continue to work in the global energy economy.\n\n"We work hard to maintain our place as the world\'s leading supplier of natural gas to the United States and to the world," the Republican presidential nominee said, via email.\n\nHowever, he said the United States had "a very small stake" in the North Dakota oil and gas industry.\n\n"It\'s time we put'}]

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=30)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Enter a prompt:  future of iran in next 5 years
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# future of iran in next 5 years. The situation is much better now."
#
# The report noted that Iran, along with Russia, is in a "very difficult situation" and that the international community should not be "condemning" the regime's move.
#
# "These sanctions are extremely damaging, and will only accelerate the destabilization in the Middle East," it said.
#
# "It's very important that the United States and its allies take the necessary steps to halt these actions, and if necessary, to prevent Iran from continuing to implement its nuclear program. This would be a necessary step."
#
# Read more:
#
# Is Iran a nuclear power?
#
# The world's top diplomat says Iran's nuclear program is a 'dangerous development'
#
# 'My son is going to die young'

# %%
# Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”


from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=30,temperature=0.7)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Enter a prompt:  he impact of technology on education
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# he impact of technology on education?
#
# We believe that the next generation of Internet access will empower individuals all over the world, helping to connect millions of people to information that they may not have expected.
#
# We believe that technology has the power to change our lives.
#
# And we believe that people won't always understand the value of technology.
#
# So how do we make sure that all people have access to the best possible education and support?
#
# Connecting everyone
#
# We believe that technology can change the world through education.
#
# We believe that technology can help us to make the most of our lives by empowering people to make choices that will shape their lives, careers and lives.
#
# Technology can also help us to understand our future and what will happen when we put technology to work.
#
# We believe that technology can help us to become better stewards of our environment and to create better, more effective communities.
#
# Technology can help us to connect more people to their knowledge and resources, especially those who are marginalized, neglected and often denied a voice in important social and economic decisions.
#
# Technology can make us better stewards of the planet, better able to lead lives that are better for our planet and for the people of the world, and that will make a difference to

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# C:\Users\ANKIT RAJ\AppData\Roaming\Python\Python312\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ANKIT RAJ\.cache\huggingface\hub\models--distilgpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': 'Artificial Intelligence will transform computer science into a field dedicated to the study and teaching of artificial intelligence. Artificial Intelligence is a field that will transform science into a field that will transform technology. Artificial Intelligence is a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that will transform a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is a field that is'}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform everything.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries.

from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40,temperature=0.8))
print("DistilGPT2:", distilgpt2(prompt, max_length=40,temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': 'Artificial Intelligence will transform our lives.\n\nWe are witnessing the first step toward a future where there are no corporate entities holding the rights and the privileges to design and build. We are in the midst of a world in which our digital data has become the basis for everything. We are making it possible, in our everyday lives, for us to be smarter than ever. We are creating a real world where people will live better lives.\n\nImagine living a life of privacy without privacy.\n\nImagine how this could change our lives and how we will all grow.\n\nWe are here to stop we are not living the dream. We are here to stop ourselves.\n\nWe are here to stop living like machines.\n\nWe are here to end the world.'}]
# DistilGPT2: [{'generated_text': "Artificial Intelligence will transform our lives so that it is possible to take action when we need it. The technology will give us the ability to do what we need to do.\n\n\n\n\nIf you're interested in learning more about Artificial Intelligence and how it works, check out:\nhttp://www.adrens.org"}]
